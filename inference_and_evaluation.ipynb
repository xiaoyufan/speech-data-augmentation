# %% [markdown]
# <a href="https://colab.research.google.com/github/xiaoyufan/speech-data-augmentation/blob/main/inference_and_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# ### Create logger

# %%
from importlib import reload
import logging
import sys

reload(logging)

LOGGING_LEVEL = 'INFO'

logger = logging.getLogger('baseline')
logger.setLevel(LOGGING_LEVEL)

formatter = logging.Formatter('[%(asctime)s - logger %(name)s - %(levelname)s] %(message)s')

ch = logging.StreamHandler(sys.stdout)
ch.setFormatter(formatter)
logger.addHandler(ch)

logger.debug('debug test')
logger.info('info test')
# Out:
# [2020-12-17 01:32:08,099 - logger baseline - INFO] info test

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Configurations

# %% [markdown]
# #### Get notebook's start time

# %%
from datetime import datetime, tzinfo
import pytz

NB_RUN_TIME = datetime.now(tz=pytz.timezone('US/Eastern')).strftime('%Y%m%d-%H%M%S')
logger.info(f'Notebook started at {NB_RUN_TIME}.')
# Out:
# [2020-12-17 01:32:08,443 - logger baseline - INFO] Notebook started at 20201216-203208.

# %% [markdown]
# #### Paths

# %%
EXPERIMENT_NAME = 'indian_added/20201216-185720-b8-e80'
PROJECT_ROOT_PATH = '/content/drive/MyDrive/nlp-project'

DATASET_PATH = f'{PROJECT_ROOT_PATH}/cmu_arctic'
TEST_DIR = f'{DATASET_PATH}/test'
WAV_TEST_DIR = f'{TEST_DIR}/audio'
TEST_FILES_PATH = f'{TEST_DIR}/test_files.csv'

INFERENCE_DIR = f'{PROJECT_ROOT_PATH}/xiaoyu-output/{EXPERIMENT_NAME}'
INFERENCE_LOG_LOCAL_PATH = '/content/inference.log'
INFERENCE_OUTPUT_DIR = f'{INFERENCE_DIR}/inferences'
INFERENCE_RESULTS_PATH = f'{INFERENCE_OUTPUT_DIR}/results.csv'
EVALUATION_RESULTS_PATH = f'{INFERENCE_OUTPUT_DIR}/evaluation.json'
MODEL_PATH = f'{INFERENCE_DIR}/models/output_graph.pb'

DEEPSPEECH_PATH = '/content/DeepSpeech'

# %% [markdown]
# ### Create non-exist directories

# %%
# !mkdir -p $INFERENCE_OUTPUT_DIR

# %% [markdown]
# ### Install packages

# %%
# %%bash -s "$DEEPSPEECH_PATH"
# DEEPSPEECH_PATH=$1
#
# if [ ! -d "$DEEPSPEECH_PATH" ] ; then
#   git clone --branch v0.9.2 https://github.com/mozilla/DeepSpeech $DEEPSPEECH_PATH
# fi
#
# cd $DEEPSPEECH_PATH
# pip install --upgrade pip==20.2.2 wheel==0.34.2 setuptools==49.6.0
# pip install --upgrade -e .
#
# # pip uninstall tensorflow -y
# pip install --upgrade tensorflow==1.15.4
# pip install tensorflow-gpu==1.15.4
#
# # Install other python packages
# pip install pandas
# # tensorflow 1.15.4 requires numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.4 which is incompatible.
# pip install --upgrade numpy==1.16.0
# Out:
# Requirement already up-to-date: pip==20.2.2 in /usr/local/lib/python3.6/dist-packages (20.2.2)
# Requirement already up-to-date: wheel==0.34.2 in /usr/local/lib/python3.6/dist-packages (0.34.2)
# Requirement already up-to-date: setuptools==49.6.0 in /usr/local/lib/python3.6/dist-packages (49.6.0)
# Obtaining file:///content/DeepSpeech
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.16.0)
# Requirement already satisfied, skipping upgrade: progressbar2 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (3.38.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyxdg in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.27)
# Requirement already satisfied, skipping upgrade: attrdict in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.0.1)
# Requirement already satisfied, skipping upgrade: absl-py in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: semver in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.13.0)
# Requirement already satisfied, skipping upgrade: opuslib==2.0.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.0.0)
# Requirement already satisfied, skipping upgrade: optuna in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.3.0)
# Requirement already satisfied, skipping upgrade: sox in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: bs4 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.0.1)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.1.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.23.0)
# Requirement already satisfied, skipping upgrade: numba==0.47.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.47.0)
# Requirement already satisfied, skipping upgrade: llvmlite==0.31.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.31.0)
# Requirement already satisfied, skipping upgrade: librosa in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.6.3)
# Requirement already satisfied, skipping upgrade: soundfile in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.10.3.post1)
# Requirement already satisfied, skipping upgrade: ds_ctcdecoder==0.9.2 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.9.2)
# Requirement already satisfied, skipping upgrade: tensorflow==1.15.4 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.15.4)
# Requirement already satisfied, skipping upgrade: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->deepspeech-training==0.9.2) (2.4.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (20.7)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (4.41.1)
# Requirement already satisfied, skipping upgrade: cliff in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (3.5.0)
# Requirement already satisfied, skipping upgrade: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.3.20)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (0.17.0)
# Requirement already satisfied, skipping upgrade: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: alembic in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.4.3)
# Requirement already satisfied, skipping upgrade: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (4.6.2)
# Requirement already satisfied, skipping upgrade: cmaes>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (0.7.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4->deepspeech-training==0.9.2) (4.6.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->deepspeech-training==0.9.2) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->deepspeech-training==0.9.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (1.24.3)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from numba==0.47.0->deepspeech-training==0.9.2) (49.6.0)
# Requirement already satisfied, skipping upgrade: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (2.1.9)
# Requirement already satisfied, skipping upgrade: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (0.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (4.4.2)
# Requirement already satisfied, skipping upgrade: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile->deepspeech-training==0.9.2) (1.14.4)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.8.1)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.2.2)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.0.8)
# Requirement already satisfied, skipping upgrade: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.15.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (3.3.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.1.2)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.34.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.2.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.34.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (3.12.4)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.12.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna->deepspeech-training==0.9.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (0.7.2)
# Requirement already satisfied, skipping upgrade: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (5.5.1)
# Requirement already satisfied, skipping upgrade: stevedore>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (3.3.0)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (3.13)
# Requirement already satisfied, skipping upgrade: cmd2!=0.8.3,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (1.4.0)
# Requirement already satisfied, skipping upgrade: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna->deepspeech-training==0.9.2) (1.0.4)
# Requirement already satisfied, skipping upgrade: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna->deepspeech-training==0.9.2) (1.1.3)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile->deepspeech-training==0.9.2) (2.20)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.4->deepspeech-training==0.9.2) (2.10.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.2) (3.3.3)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.2) (1.0.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna->deepspeech-training==0.9.2) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyperclip>=1.6 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (1.8.1)
# Requirement already satisfied, skipping upgrade: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (0.2.5)
# Requirement already satisfied, skipping upgrade: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (20.3.0)
# Requirement already satisfied, skipping upgrade: colorama>=0.3.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (0.4.4)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna->deepspeech-training==0.9.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna->deepspeech-training==0.9.2) (3.4.0)
# Installing collected packages: deepspeech-training
#   Attempting uninstall: deepspeech-training
#     Found existing installation: deepspeech-training 0.9.2
#     Can't uninstall 'deepspeech-training'. No files were found to uninstall.
#   Running setup.py develop for deepspeech-training
# Successfully installed deepspeech-training
# Requirement already up-to-date: tensorflow==1.15.4 in /usr/local/lib/python3.6/dist-packages (1.15.4)
# Requirement already satisfied, skipping upgrade: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.8.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.34.2)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.0.8)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.2.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (3.3.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.1.2)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.2.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (3.12.4)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.12.1)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.16.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.34.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.3.3)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (1.0.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (49.6.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.4) (2.10.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.1.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.4.0)
# Requirement already satisfied: tensorflow-gpu==1.15.4 in /usr/local/lib/python3.6/dist-packages (1.15.4)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.34.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.2.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.16.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (3.3.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (3.12.4)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.4) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.15.4) (49.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.3.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already up-to-date: numpy==1.16.0 in /usr/local/lib/python3.6/dist-packages (1.16.0)

# %%
# %%bash
#
# pip install --upgrade deepspeech-gpu==0.9.2
# Out:
# Requirement already up-to-date: deepspeech-gpu==0.9.2 in /usr/local/lib/python3.6/dist-packages (0.9.2)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from deepspeech-gpu==0.9.2) (1.16.0)

# %% [markdown]
# #  Inference

# %% [markdown]
# ## Run inference

# %%
# %%bash -s "$MODEL_PATH" "$WAV_TEST_DIR" "$INFERENCE_LOG_LOCAL_PATH" "$INFERENCE_OUTPUT_DIR"
# MODEL_PATH=$1
# WAV_TEST_DIR=$2
# INFERENCE_LOG_LOCAL_PATH=$3
# INFERENCE_OUTPUT_DIR=$4
#
# rm $INFERENCE_LOG_LOCAL_PATH
#
# for file in $WAV_TEST_DIR/**/*.wav; do
#   echo "=========================="
#   echo "Running inference on $file"
#   deepspeech --model $MODEL_PATH --audio $file
# done 2>&1 | tee -a $INFERENCE_LOG_LOCAL_PATH
#
# cp $INFERENCE_LOG_LOCAL_PATH $INFERENCE_OUTPUT_DIR/inference.log
# Out:
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0161.wav
# 2020-12-17 01:32:29.355128: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:32:29.478676: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:32:29.480361: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:32:29.513308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:29.513973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:32:29.514004: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:32:29.521946: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:32:29.528037: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:32:29.528966: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:32:29.533657: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:32:29.535198: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:32:29.540779: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:32:29.540904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:29.541592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:29.542153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:32:30.000958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:32:30.000998: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:32:30.001005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:32:30.001160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:30.001816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:30.002432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:30.002981: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:32:30.003028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:32:38.499697: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 4.65s.
# Running inference.
# Inference took 5.322s for 3.485s audio file.
# dac o wa their fomen and thit wath in de wor orproup
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0162.wav
# 2020-12-17 01:32:39.748674: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:32:39.866563: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:32:39.867999: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:32:39.898691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:39.899354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:32:39.899392: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:32:39.901319: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:32:39.903019: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:32:39.903360: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:32:39.905223: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:32:39.906391: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:32:39.910321: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:32:39.910433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:39.911067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:39.911652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:32:40.369833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:32:40.369873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:32:40.369880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:32:40.370003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:40.370661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:40.371209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:40.371754: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:32:40.371794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:32:45.558827: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.27s.
# Running inference.
# Inference took 5.244s for 2.795s audio file.
# dachs tasub fomennixplangd thorp
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0163.wav
# 2020-12-17 01:32:46.679956: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:32:46.799913: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:32:46.801259: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:32:46.831659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:46.832274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:32:46.832303: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:32:46.834044: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:32:46.835658: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:32:46.836000: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:32:46.837717: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:32:46.838746: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:32:46.842473: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:32:46.842556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:46.843153: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:46.843714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:32:47.291347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:32:47.291403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:32:47.291410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:32:47.291569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:47.292243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:47.292824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:47.293372: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:32:47.293420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:32:52.502599: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.25s.
# Running inference.
# Inference took 5.198s for 2.495s audio file.
# philip mat now ath erd to fallow
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0164.wav
# 2020-12-17 01:32:53.549057: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:32:53.666020: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:32:53.667560: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:32:53.697806: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:53.698494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:32:53.698529: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:32:53.700498: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:32:53.702135: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:32:53.702472: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:32:53.704404: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:32:53.705495: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:32:53.709493: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:32:53.709598: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:53.710210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:53.710758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:32:54.165708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:32:54.165751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:32:54.165760: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:32:54.165883: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:54.166582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:54.167197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:32:54.167784: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:32:54.167823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:32:59.276057: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.25s.
# Running inference.
# Inference took 5.488s for 4.335s audio file.
# hea cam frirestia yerra go andre yeldimself to jn
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0165.wav
# 2020-12-17 01:33:00.701654: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:00.817505: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:00.818996: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:00.850320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:00.851017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:00.851051: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:00.852940: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:00.854767: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:00.855106: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:00.857041: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:00.858142: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:00.861815: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:00.861928: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:00.862597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:00.863187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:01.316390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:01.316427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:01.316434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:01.316549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:01.317257: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:01.317865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:01.318454: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:33:01.318496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:33:06.622290: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.25s.
# Running inference.
# Inference took 5.410s for 3.005s audio file.
# the are twi sack or cap do mom mit
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0166.wav
# 2020-12-17 01:33:07.778674: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:07.896652: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:07.898260: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:07.929725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:07.930411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:07.930446: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:07.932375: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:07.934141: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:07.934519: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:07.936385: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:07.937545: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:07.941481: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:07.941584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:07.942275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:07.942887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:08.402247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:08.402286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:08.402293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:08.402428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:08.403020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:08.403631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:08.404197: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:33:08.404267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:33:13.574029: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.26s.
# Running inference.
# Inference took 5.492s for 3.935s audio file.
# two days agon jeang thorand wer herfothars man mor hihting
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0167.wav
# 2020-12-17 01:33:14.950090: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:15.071916: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:15.073272: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:15.102476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.103084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:15.103130: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:15.104949: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:15.106614: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:15.106939: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:15.108860: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:15.110044: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:15.113831: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:15.113921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.114590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.115213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:15.569637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:15.569681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:15.569687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:15.569833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.570507: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.571121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:15.571700: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:33:15.571741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:33:20.711281: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.25s.
# Running inference.
# Inference took 5.171s for 2.665s audio file.
# i was ad the caen an siyou
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0168.wav
# 2020-12-17 01:33:21.793646: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:21.909430: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:21.910857: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:21.941970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:21.942624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:21.942673: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:21.944722: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:21.946546: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:21.946902: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:21.948777: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:21.949919: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:21.953772: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:21.953874: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:21.954547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:21.955078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:22.410826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:22.410887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:22.410899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:22.411073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:22.411778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:22.412418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:22.412998: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:33:22.413054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:33:27.592746: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.27s.
# Running inference.
# Inference took 5.384s for 3.455s audio file.
# lo be shwat tomin the face in leth nos stang
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0169.wav
# 2020-12-17 01:33:28.857708: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:28.980456: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:28.981970: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:29.011210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.011908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:29.011937: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:29.013838: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:29.015636: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:29.015976: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:29.017780: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:29.018910: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:29.022647: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:29.022750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.023395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.023958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:29.474963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:29.475005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:29.475013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:29.475174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.475836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.476458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:29.477023: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:33:29.477065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:33:34.611161: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.26s.
# Running inference.
# Inference took 5.162s for 2.645s audio file.
# suddely teane stoped for n ansins
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0170.wav
# 2020-12-17 01:33:35.710126: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:33:35.829033: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:33:35.830652: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:33:35.861119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:35.861785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:33:35.861812: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:33:35.863724: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:33:35.865465: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:33:35.865790: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:33:35.867734: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:33:35.868846: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:33:35.872701: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:33:35.872803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:35.873463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:33:35.873981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:33:36.328938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:33:36.328979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:33:36.328989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:33:36.329125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
# 2020-12-17 01:45:56.623986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:45:56.624531: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:45:56.624566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:46:01.799348: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.27s.
# Running inference.
# Inference took 5.330s for 3.335s audio file.
# sicadu to whys trever cils por turnclose
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0198.wav
# 2020-12-17 01:46:03.025370: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:46:03.145774: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:46:03.147335: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:46:03.177970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.178685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:46:03.178718: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:46:03.180678: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:46:03.182516: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:46:03.182908: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:46:03.184793: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:46:03.185990: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:46:03.189995: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:46:03.190101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.190736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.191287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:46:03.643813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:46:03.643855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:46:03.643863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:46:03.643998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.644603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.645159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:03.645732: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:46:03.645780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:46:08.819717: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.26s.
# Running inference.
# Inference took 5.220s for 2.625s audio file.
# som thimes ur trames er fild a fisiins
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0199.wav
# 2020-12-17 01:46:09.919138: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:46:10.034923: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:46:10.036421: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:46:10.069279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.069938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:46:10.069967: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:46:10.071972: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:46:10.073866: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:46:10.074189: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:46:10.076146: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:46:10.077302: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:46:10.081170: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:46:10.081304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.081927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.082497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:46:10.537345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:46:10.537397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:46:10.537408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:46:10.537568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.538211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.538851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:10.539450: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:46:10.539499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:46:15.725790: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.26s.
# Running inference.
# Inference took 5.326s for 2.965s audio file.
# da sad the rowp gildin as qcropered him fir tha s bay
# ==========================
# Running inference on /content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0200.wav
# 2020-12-17 01:46:16.925040: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.2-0-gb2920c7
# Warning: reading entire model file into memory. Transform model file into an mmapped graph to reduce heap usage.
# 2020-12-17 01:46:17.056876: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-17 01:46:17.058353: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-17 01:46:17.086543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.087211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2020-12-17 01:46:17.087257: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-17 01:46:17.089181: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-12-17 01:46:17.091002: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-12-17 01:46:17.091328: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-12-17 01:46:17.093273: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-12-17 01:46:17.094353: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-12-17 01:46:17.098210: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-12-17 01:46:17.098351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.098983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.099540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-12-17 01:46:17.562602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-12-17 01:46:17.562642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-12-17 01:46:17.562649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-12-17 01:46:17.562772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.563377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.563932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-17 01:46:17.564550: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-12-17 01:46:17.564599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14828 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0)
# 2020-12-17 01:46:22.765169: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Loading model from file /content/drive/MyDrive/nlp-project/xiaoyu-output/indian_added/20201216-185720-b8-e80/models/output_graph.pb
# Loaded model in 1.28s.
# Running inference.
# Inference took 5.258s for 2.805s audio file.
# he nop thegan an aclub cogt him want more

# %% [markdown]
# ## Collect hypothesis

# %%
# %%bash
#
# pip install jiwer
# Out:
# Requirement already satisfied: jiwer in /usr/local/lib/python3.6/dist-packages (2.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from jiwer) (1.16.0)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.6/dist-packages (from jiwer) (0.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein->jiwer) (49.6.0)

# %%
import jiwer
import re

transformation = jiwer.Compose([
  jiwer.ToLowerCase(),
  jiwer.RemoveWhiteSpace(replace_by_space=True),
  jiwer.RemoveMultipleSpaces(),
  jiwer.Strip(),
]) 

PUNCTUATIONS_TO_REMOVE = re.compile(r'[!"#$%&()*\+,-./\\:;<=>?@\[\]^_`{|}~]')

def process_hypothesis(raw):
  processed = re.sub(PUNCTUATIONS_TO_REMOVE, ' ', raw)
  processed = transformation(processed)
  return processed

# %%
import pandas

from pathlib import Path

RESULTS_FILE_COLUMNS = ['wav_filename', 'hypothesis', 'ground_truth', 'category']

test_files_df = pandas.read_csv(TEST_FILES_PATH)

with open(INFERENCE_LOG_LOCAL_PATH) as file:
  data = []

  for line in file:
    # Remove the trailing newline character
    line = line.rstrip()    

    # Find wav filename
    if line.startswith('Running inference on'):
      wav_filename = line.replace('Running inference on ', '')
      continue
    
    # Find predicted text
    if line.startswith('Inference took'):
      raw_hypothesis = next(file, None)
      hypothesis = process_hypothesis(raw_hypothesis)

      if wav_filename:
        test_data_loc = test_files_df.loc[test_files_df['wav_filename'] == wav_filename]
        ground_truth = test_data_loc['transcript'].iloc[0]
        
        category = Path(wav_filename).parts[-2]

      logger.debug(f'wav_filename: {wav_filename}, hypothesis: {hypothesis}, ground_truth: {ground_truth}, category: {category}')

      # if wav_filename and predicted and ground_truth:
      if predicted and ground_truth and category:
        data.append((wav_filename, hypothesis, ground_truth, category))
      else:
        logger.warn(f'Data is incomplete. Not writing to the result file')

      wav_filename = None
      hypothesis = None
      ground_truth = None

    df = pandas.DataFrame(data=data, columns=RESULTS_FILE_COLUMNS)
    df.to_csv(INFERENCE_RESULTS_PATH, index=False)

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Run evaluation

# %%
def levenshtein(a, b):
  "Calculates the Levenshtein distance between a and b."
  n, m = len(a), len(b)
  if n > m:
    # Make sure n <= m, to use O(min(n,m)) space
    a, b = b, a
    n, m = m, n

  current = list(range(n+1))
  for i in range(1, m+1):
    previous, current = current, [i]+[0]*n
    for j in range(1, n+1):
      add, delete = previous[j]+1, current[j-1]+1
      change = previous[j-1]
      if a[j-1] != b[i-1]:
        change = change + 1
      current[j] = min(add, delete, change)

  return current[n]

def compute_cer(ground_truth, hypothesis):
  ground_truth_str = ''.join(ground_truth)
  hypothesis_str = ''.join(hypothesis)
  return levenshtein(ground_truth_str, hypothesis_str) / len(ground_truth_str)

# %%
import jiwer
import json
import pandas

CATEGORIES = ['all', 'female_40', 'male_40', 'indian_male_40']

evaluation = {}

results_df = pandas.read_csv(INFERENCE_RESULTS_PATH)

for category in CATEGORIES:
  if category == 'all':
    rows = results_df
  else:
    rows = results_df[results_df['category'].eq(category)]

  ground_truth = rows['ground_truth'].tolist()
  hypothesis = rows['hypothesis'].tolist()
  
  measures = jiwer.compute_measures(ground_truth, hypothesis)
  measures['cer'] = compute_cer(ground_truth, hypothesis)
  evaluation[category] = measures

logger.info('Evaluation:')
logger.info(json.dumps(evaluation, indent=2))

with open(EVALUATION_RESULTS_PATH, 'w') as file:
  json.dump(evaluation, file, indent=2)
# Out:
# [2020-12-17 01:47:07,165 - logger baseline - INFO] Evaluation:
# [2020-12-17 01:47:07,166 - logger baseline - INFO] {
#   "all": {
#     "wer": 0.8226744186046512,
#     "mer": 0.8101145038167938,
#     "wil": 0.959902756514625,
#     "wip": 0.040097243485375,
#     "hits": 199,
#     "substitutions": 742,
#     "deletions": 91,
#     "insertions": 16,
#     "cer": 0.36133333333333334
#   },
#   "female_40": {
#     "wer": 0.8313953488372093,
#     "mer": 0.8194842406876791,
#     "wil": 0.9633720930232558,
#     "wip": 0.03662790697674419,
#     "hits": 63,
#     "substitutions": 247,
#     "deletions": 34,
#     "insertions": 5,
#     "cer": 0.3617142857142857
#   },
#   "male_40": {
#     "wer": 0.7994186046511628,
#     "mer": 0.7834757834757835,
#     "wil": 0.9481768590295722,
#     "wip": 0.05182314097042779,
#     "hits": 76,
#     "substitutions": 241,
#     "deletions": 27,
#     "insertions": 7,
#     "cer": 0.31542857142857145
#   },
#   "indian_male_40": {
#     "wer": 0.8401162790697675,
#     "mer": 0.828080229226361,
#     "wil": 0.9670908293111014,
#     "wip": 0.03290917068889864,
#     "hits": 60,
#     "substitutions": 253,
#     "deletions": 31,
#     "insertions": 5,
#     "cer": 0.40685714285714286
#   }
# }
