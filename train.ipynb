# %% [markdown]
# <a href="https://colab.research.google.com/github/xiaoyufan/speech-data-augmentation/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocess data

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Create logger

# %%
from importlib import reload
import logging
import sys

reload(logging)

LOGGING_LEVEL = 'DEBUG'

logger = logging.getLogger('baseline')
logger.setLevel(LOGGING_LEVEL)

formatter = logging.Formatter('[%(asctime)s - logger %(name)s - %(levelname)s] %(message)s')

ch = logging.StreamHandler(sys.stdout)
ch.setFormatter(formatter)
logger.addHandler(ch)

logger.debug('debug test')
logger.info('info test')
# Out:
# [2020-12-16 20:48:32,881 - logger baseline - DEBUG] debug test
# [2020-12-16 20:48:32,882 - logger baseline - INFO] info test

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Configurations

# %% [markdown]
# #### Configure mode

# %%
MODES = {
  'BASELINE': 'baseline',
}
MODE =  MODES['BASELINE']
logger.info(f'Notebook runs in {MODE} mode.')
# Out:
# [2020-12-16 20:48:33,824 - logger baseline - INFO] Notebook runs in baseline mode.

# %% [markdown]
# #### Get notebook's start time

# %%
from datetime import datetime, tzinfo
import pytz

NB_RUN_TIME = datetime.now(tz=pytz.timezone('US/Eastern')).strftime('%Y%m%d-%H%M%S')
logger.info(f'Notebook started at {NB_RUN_TIME}.')
# Out:
# [2020-12-16 20:48:33,833 - logger baseline - INFO] Notebook started at 20201216-154833.

# %% [markdown]
# #### Hyperparameters

# %%
TRAIN_BATCH_SIZE=8
EPOCHS=80

# %% [markdown]
# #### Other configurations

# %%
DEEPSPEECH_LOG_LEVEL = '1'
DEEPSPEECH_PATH = '/content/DeepSpeech'
PROJECT_ROOT_PATH = '/content/drive/MyDrive/nlp-project'
DATASET_PATH = f'{PROJECT_ROOT_PATH}/cmu_arctic'
FORCE_TRANSFORM_DATA = True

# %% [markdown]
# #### Set input and output paths

# %%
TEST_DIR = 'test'
TEST_FILES_PATH = f'{DATASET_PATH}/{TEST_DIR}/test_files.csv'
WAV_TEST_DIR = f'{DATASET_PATH}/{TEST_DIR}/audio'

if MODE == MODES['BASELINE']:
  TRAIN_DIR = 'train_baseline'
  TRAIN_FILES_PATH = f'{DATASET_PATH}/{TRAIN_DIR}/train_files.csv'
  WAV_TRAIN_DIR = f'{DATASET_PATH}/{TRAIN_DIR}/audio'

  OUTPUT_PATH = f'{PROJECT_ROOT_PATH}/xiaoyu-baseline/{NB_RUN_TIME}-b{TRAIN_BATCH_SIZE}-e{EPOCHS}'
else:
  raise NotImplementedError

# %% [markdown]
# ### Install packages

# %%
# %%bash -s "$DEEPSPEECH_PATH"
# DEEPSPEECH_PATH=$1
#
# if [ ! -d "$DEEPSPEECH_PATH" ] ; then
#   git clone --branch v0.9.2 https://github.com/mozilla/DeepSpeech $DEEPSPEECH_PATH
# fi
#
# cd $DEEPSPEECH_PATH
# pip install --upgrade pip==20.2.2 wheel==0.34.2 setuptools==49.6.0
# pip install --upgrade -e .
#
# # pip uninstall tensorflow -y
# pip install --upgrade tensorflow==1.15.4
# pip install tensorflow-gpu==1.15.4
#
# # Install other packages
# pip install pandas
# # tensorflow 1.15.4 requires numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.4 which is incompatible.
# pip install --upgrade numpy==1.16.0
# Out:
# Requirement already up-to-date: pip==20.2.2 in /usr/local/lib/python3.6/dist-packages (20.2.2)
# Requirement already up-to-date: wheel==0.34.2 in /usr/local/lib/python3.6/dist-packages (0.34.2)
# Requirement already up-to-date: setuptools==49.6.0 in /usr/local/lib/python3.6/dist-packages (49.6.0)
# Obtaining file:///content/DeepSpeech
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.16.0)
# Requirement already satisfied, skipping upgrade: progressbar2 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (3.38.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyxdg in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.27)
# Requirement already satisfied, skipping upgrade: attrdict in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.0.1)
# Requirement already satisfied, skipping upgrade: absl-py in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: semver in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.13.0)
# Requirement already satisfied, skipping upgrade: opuslib==2.0.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.0.0)
# Requirement already satisfied, skipping upgrade: optuna in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.3.0)
# Requirement already satisfied, skipping upgrade: sox in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: bs4 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.0.1)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.1.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (2.23.0)
# Requirement already satisfied, skipping upgrade: numba==0.47.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.47.0)
# Requirement already satisfied, skipping upgrade: llvmlite==0.31.0 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.31.0)
# Requirement already satisfied, skipping upgrade: librosa in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.6.3)
# Requirement already satisfied, skipping upgrade: soundfile in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.10.3.post1)
# Requirement already satisfied, skipping upgrade: ds_ctcdecoder==0.9.2 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (0.9.2)
# Requirement already satisfied, skipping upgrade: tensorflow==1.15.4 in /usr/local/lib/python3.6/dist-packages (from deepspeech-training==0.9.2) (1.15.4)
# Requirement already satisfied, skipping upgrade: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->deepspeech-training==0.9.2) (2.4.0)
# Requirement already satisfied, skipping upgrade: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (4.6.2)
# Requirement already satisfied, skipping upgrade: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.3.20)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (20.7)
# Requirement already satisfied, skipping upgrade: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: alembic in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (1.4.3)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (4.41.1)
# Requirement already satisfied, skipping upgrade: cliff in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (3.5.0)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (0.17.0)
# Requirement already satisfied, skipping upgrade: cmaes>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from optuna->deepspeech-training==0.9.2) (0.7.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4->deepspeech-training==0.9.2) (4.6.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->deepspeech-training==0.9.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->deepspeech-training==0.9.2) (2018.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->deepspeech-training==0.9.2) (3.0.4)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from numba==0.47.0->deepspeech-training==0.9.2) (49.6.0)
# Requirement already satisfied, skipping upgrade: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (4.4.2)
# Requirement already satisfied, skipping upgrade: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (0.2.2)
# Requirement already satisfied, skipping upgrade: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (2.1.9)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa->deepspeech-training==0.9.2) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile->deepspeech-training==0.9.2) (1.14.4)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.34.2)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.12.1)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.15.1)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.1.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.1.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.34.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.2.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (3.12.4)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.2.2)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (3.3.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.0.8)
# Requirement already satisfied, skipping upgrade: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->deepspeech-training==0.9.2) (0.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna->deepspeech-training==0.9.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna->deepspeech-training==0.9.2) (1.1.3)
# Requirement already satisfied, skipping upgrade: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna->deepspeech-training==0.9.2) (1.0.4)
# Requirement already satisfied, skipping upgrade: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (5.5.1)
# Requirement already satisfied, skipping upgrade: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (0.7.2)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (3.13)
# Requirement already satisfied, skipping upgrade: stevedore>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (3.3.0)
# Requirement already satisfied, skipping upgrade: cmd2!=0.8.3,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna->deepspeech-training==0.9.2) (1.4.0)
# Requirement already satisfied, skipping upgrade: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile->deepspeech-training==0.9.2) (2.20)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.4->deepspeech-training==0.9.2) (2.10.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.2) (3.3.3)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->deepspeech-training==0.9.2) (1.0.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna->deepspeech-training==0.9.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore>=2.0.1->cliff->optuna->deepspeech-training==0.9.2) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyperclip>=1.6 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (1.8.1)
# Requirement already satisfied, skipping upgrade: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (20.3.0)
# Requirement already satisfied, skipping upgrade: colorama>=0.3.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (0.4.4)
# Requirement already satisfied, skipping upgrade: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna->deepspeech-training==0.9.2) (0.2.5)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore>=2.0.1->cliff->optuna->deepspeech-training==0.9.2) (3.4.0)
# Installing collected packages: deepspeech-training
#   Attempting uninstall: deepspeech-training
#     Found existing installation: deepspeech-training 0.9.2
#     Can't uninstall 'deepspeech-training'. No files were found to uninstall.
#   Running setup.py develop for deepspeech-training
# Successfully installed deepspeech-training
# Requirement already up-to-date: tensorflow==1.15.4 in /usr/local/lib/python3.6/dist-packages (1.15.4)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.2.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.1.2)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.16.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.0.8)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (3.3.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.2.2)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.12.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (3.12.4)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.34.0)
# Requirement already satisfied, skipping upgrade: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.8.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (0.34.2)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4) (1.15.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.4) (2.10.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15.4) (49.6.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.3.3)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (1.0.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.1.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4) (3.4.0)
# Requirement already satisfied: tensorflow-gpu==1.15.4 in /usr/local/lib/python3.6/dist-packages (1.15.4)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.1.2)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.2.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (3.3.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.0.8)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.34.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.10.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (0.34.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.4) (3.12.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.4) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (49.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.3.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.4) (3.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already up-to-date: numpy==1.16.0 in /usr/local/lib/python3.6/dist-packages (1.16.0)

# %% [markdown]
# ### Check tensorflow version and if it runs on GPU

# %%
import tensorflow as tf
logger.info(f'tensorflow version: {tf.__version__}')

if tf.test.gpu_device_name(): 
    logger.info('Using Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
   logger.info("Not using GPU")
# Out:
# [2020-12-16 20:48:50,071 - logger baseline - INFO] tensorflow version: 1.15.4
# [2020-12-16 20:48:50,085 - logger baseline - INFO] Using Default GPU Device: /device:GPU:0

# %% [markdown]
# ## Transform CMU arctic dataset into DeepSpeech format

# %% [markdown]
# ### Preprocess transcripts

# %%
# %%bash
#
# pip install jiwer
# Out:
# Requirement already satisfied: jiwer in /usr/local/lib/python3.6/dist-packages (2.2.0)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.6/dist-packages (from jiwer) (0.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from jiwer) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein->jiwer) (49.6.0)

# %%
import jiwer
import re

transformation = jiwer.Compose([
  jiwer.ToLowerCase(),
  jiwer.RemoveWhiteSpace(replace_by_space=True),
  jiwer.RemoveMultipleSpaces(),
  jiwer.Strip(),
]) 

PUNCTUATIONS_TO_REMOVE = re.compile(r'[!"#$%&()*\+,-./\\:;<=>?@\[\]^_`{|}~]')


def preprocess_transcript(raw):
  processed = re.sub(PUNCTUATIONS_TO_REMOVE, ' ', raw)
  processed = transformation(processed)
  return processed

# %% [markdown]
# ### Generate data files

# %%
# Importer

import os
import pandas
import sys

from pathlib import Path


def load_data_file():
  data_file_path = f'{DATASET_PATH}/cmuarctic.data.txt'

  with open(data_file_path) as file:
    data_file = {}

    for line in file:
      wav_filename = (line.split('"')[0]).split(' ')[1]
      transcript = line.split('"')[1]
      data_file[wav_filename] = transcript

    return data_file


def generate_files_list(wav_dir, output_path):
  COLUMNS = ['wav_filename', 'wav_filesize', 'transcript']
  files_list_data = []

  data_file = load_data_file()

  for path in Path(wav_dir).rglob('*.wav'):
    wav_path_relative_to_wav_dir = str(path.relative_to(wav_dir))
    wav_filename = path.name
    raw_transcript = data_file[wav_filename.replace(path.suffix, '')]
    transcript = preprocess_transcript(raw_transcript) 

    logger.debug(f'Wav: {wav_path_relative_to_wav_dir}; Transcript: {transcript}')

    file_data = (str(path), path.stat().st_size, transcript)
    files_list_data.append(file_data)
          
  df = pandas.DataFrame(data=files_list_data, columns=COLUMNS)
  df.to_csv(os.path.join(output_path), index=False)


def transform_data():
    if (not FORCE_TRANSFORM_DATA and
        os.path.exists(TRAIN_FILES_PATH) and
        os.path.exists(TEST_FILES_PATH)):
      logger.info(f'Skipping transforming data. Data files {TRAIN_FILES_PATH} and {TEST_FILES_PATH} already exist. ')
      return

    # Generate files list
    generate_files_list(wav_dir=WAV_TRAIN_DIR, output_path=TRAIN_FILES_PATH)
    generate_files_list(wav_dir=WAV_TEST_DIR, output_path=TEST_FILES_PATH)

    logger.info(f'Train data files generated at {TRAIN_FILES_PATH}.')
    logger.info(f'Test data files generated at {TEST_FILES_PATH}.')

# %%
transform_data()
- logger baseline - DEBUG] Wav: indian_male_40/arctic_a0173.wav; Transcript: the date was nearly eighteen years old
# [2020-12-16 20:48:53,731 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0168.wav; Transcript: low bush whipped him in the face and left no sting
# [2020-12-16 20:48:53,732 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0164.wav; Transcript: he came first a year ago and revealed himself to jeanne
# [2020-12-16 20:48:53,733 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0174.wav; Transcript: they were the presage of storm
# [2020-12-16 20:48:53,736 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0192.wav; Transcript: he did not rush in
# [2020-12-16 20:48:53,737 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0176.wav; Transcript: for the first time in his life he was yearning for a scrap
# [2020-12-16 20:48:53,738 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0189.wav; Transcript: the big eyed clucking moose birds were most annoying
# [2020-12-16 20:48:53,739 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0186.wav; Transcript: like a flash he launched himself into the feathered mass of the owl
# [2020-12-16 20:48:53,740 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0178.wav; Transcript: every bone in her aged body seemed broken or dislocated
# [2020-12-16 20:48:53,742 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0165.wav; Transcript: they are to attack your camp tomorrow night
# [2020-12-16 20:48:53,744 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0193.wav; Transcript: it was edged with ice
# [2020-12-16 20:48:53,745 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0166.wav; Transcript: two days ago jeanne learned where her father's men were hiding
# [2020-12-16 20:48:53,746 - logger baseline - DEBUG] Wav: indian_male_40/arctic_a0187.wav; Transcript: ahead of them they saw a glimmer of sunshine
# [2020-12-16 20:48:53,757 - logger baseline - INFO] Train data files generated at /content/drive/MyDrive/nlp-project/cmu_arctic/train_baseline/train_files.csv.
# [2020-12-16 20:48:53,758 - logger baseline - INFO] Test data files generated at /content/drive/MyDrive/nlp-project/cmu_arctic/test/test_files.csv.

# %% [markdown]
# # Train a baseline model
#
# Train a DeepSpeech model with Kaggle Tensorflow challenge's dataset to establish the baseline.

# %%
# %%bash -s "$DEEPSPEECH_PATH" "$TRAIN_FILES_PATH" "$TEST_FILES_PATH" "$OUTPUT_PATH" "$DEEPSPEECH_LOG_LEVEL" "$NB_RUN_TIME" "$DATASET_PATH" "$TRAIN_BATCH_SIZE" "$EPOCHS"
#
# DEEPSPEECH_PATH=$1
# TRAIN_FILES_PATH=$2
# TEST_FILES_PATH=$3
# OUTPUT_PATH=$4
# DEEPSPEECH_LOG_LEVEL=$5
# NB_RUN_TIME=$6
# DATASET_PATH=$7
# TRAIN_BATCH_SIZE=$8
# EPOCHS=$9
#
# cd $DEEPSPEECH_PATH
#
# echo "===== Configurations =====
# Dataset used: $DATASET_PATH
# TRAIN_BATCH_SIZE: $TRAIN_BATCH_SIZE
# EPOCHS: $EPOCHS
# " 2>&1 | tee -a "$NB_RUN_TIME.log"
#
# python DeepSpeech.py \
#   --alphabet_config_path "$DATASET_PATH/alphabet.txt" \
#   --train_files "$TRAIN_FILES_PATH" \
#   --test_files "$TEST_FILES_PATH" \
#   --checkpoint_dir "$OUTPUT_PATH/checkpoints" \
#   --export_dir "$OUTPUT_PATH/models" \
#   --train_batch_size $TRAIN_BATCH_SIZE \
#   --epochs $EPOCHS \
#   --log_level "$DEEPSPEECH_LOG_LEVEL" \
#   --test_output_file "$OUTPUT_PATH/test-output.txt" \
#   --summary_dir "$OUTPUT_PATH/summary" 2>&1 | tee -a "$NB_RUN_TIME.log"
#
# cp "$NB_RUN_TIME.log" "$OUTPUT_PATH/log.txt"
# Out:
# ===== Configurations =====
# Dataset used: /content/drive/MyDrive/nlp-project/cmu_arctic
# TRAIN_BATCH_SIZE: 8
# EPOCHS: 80
#
# 2020-12-16 20:48:55.674890: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I1216 20:48:56.139809 139703907256192 utils.py:141] NumExpr defaulting to 4 threads.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:347: Iterator.output_types (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(iterator)`.
# W1216 20:48:57.048589 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:347: Iterator.output_types (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:348: Iterator.output_shapes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(iterator)`.
# W1216 20:48:57.048823 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:348: Iterator.output_shapes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:350: Iterator.output_classes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_classes(iterator)`.
# W1216 20:48:57.048995 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:350: Iterator.output_classes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_classes(iterator)`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W1216 20:48:57.128085 139703907256192 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/rnn/python/ops/lstm_ops.py:597: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W1216 20:48:57.129921 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/rnn/python/ops/lstm_ops.py:597: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /content/DeepSpeech/training/deepspeech_training/train.py:249: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1216 20:48:57.197585 139703907256192 deprecation.py:323] From /content/DeepSpeech/training/deepspeech_training/train.py:249: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# I Could not find best validating checkpoint.
# I Could not find most recent checkpoint.
# I Initializing all variables.
# I STARTING Optimization
# Epoch 0 |   Training | Elapsed Time: 0:00:23 | Steps: 85 | Loss: 149.187991
# --------------------------------------------------------------------------------
# Epoch 1 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 139.944759
# --------------------------------------------------------------------------------
# Epoch 2 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 139.540849
# --------------------------------------------------------------------------------
# Epoch 3 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 137.400672
# --------------------------------------------------------------------------------
# Epoch 4 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 133.698626
# --------------------------------------------------------------------------------
# Epoch 5 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 123.613295
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W1216 20:51:20.883380 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# --------------------------------------------------------------------------------
# Epoch 6 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 103.375278
# --------------------------------------------------------------------------------
# Epoch 7 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 86.342558
# --------------------------------------------------------------------------------
# Epoch 8 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 74.297189
# --------------------------------------------------------------------------------
# Epoch 9 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 64.876508
# --------------------------------------------------------------------------------
# Epoch 10 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 57.548469
# --------------------------------------------------------------------------------
# Epoch 11 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 50.876170
# --------------------------------------------------------------------------------
# Epoch 12 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 43.775036
# --------------------------------------------------------------------------------
# Epoch 13 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 36.750402
# --------------------------------------------------------------------------------
# Epoch 14 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 31.905568
# --------------------------------------------------------------------------------
# Epoch 15 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 27.180687
# --------------------------------------------------------------------------------
# Epoch 16 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 24.169362
# --------------------------------------------------------------------------------
# Epoch 17 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 20.579730
# --------------------------------------------------------------------------------
# Epoch 18 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 18.872496
# --------------------------------------------------------------------------------
# Epoch 19 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 15.832858
# --------------------------------------------------------------------------------
# Epoch 20 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 14.866463
# --------------------------------------------------------------------------------
# Epoch 21 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 11.598414
# --------------------------------------------------------------------------------
# Epoch 22 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 10.244358
# --------------------------------------------------------------------------------
# Epoch 23 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 7.839287
# --------------------------------------------------------------------------------
# Epoch 24 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 6.780060
# --------------------------------------------------------------------------------
# Epoch 25 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 5.892074
# --------------------------------------------------------------------------------
# Epoch 26 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 5.423047
# --------------------------------------------------------------------------------
# Epoch 27 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 4.620900
# --------------------------------------------------------------------------------
# Epoch 28 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 4.187403
# --------------------------------------------------------------------------------
# Epoch 29 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 4.052731
# --------------------------------------------------------------------------------
# Epoch 30 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.679678
# --------------------------------------------------------------------------------
# Epoch 31 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.338420
# --------------------------------------------------------------------------------
# Epoch 32 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.572797
# --------------------------------------------------------------------------------
# Epoch 33 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.916206
# --------------------------------------------------------------------------------
# Epoch 34 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.204639
# --------------------------------------------------------------------------------
# Epoch 35 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.266211
# --------------------------------------------------------------------------------
# Epoch 36 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.674838
# --------------------------------------------------------------------------------
# Epoch 37 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 3.333303
# --------------------------------------------------------------------------------
# Epoch 38 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.744643
# --------------------------------------------------------------------------------
# Epoch 39 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.528469
# --------------------------------------------------------------------------------
# Epoch 40 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.544115
# --------------------------------------------------------------------------------
# Epoch 41 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.548810
# --------------------------------------------------------------------------------
# Epoch 42 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.679023
# --------------------------------------------------------------------------------
# Epoch 43 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.332939
# --------------------------------------------------------------------------------
# Epoch 44 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.047081
# --------------------------------------------------------------------------------
# Epoch 45 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.301592
# --------------------------------------------------------------------------------
# Epoch 46 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.405047
# --------------------------------------------------------------------------------
# Epoch 47 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.111042
# --------------------------------------------------------------------------------
# Epoch 48 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.613353
# --------------------------------------------------------------------------------
# Epoch 49 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.765856
# --------------------------------------------------------------------------------
# Epoch 50 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.022703
# --------------------------------------------------------------------------------
# Epoch 51 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.120484
# --------------------------------------------------------------------------------
# Epoch 52 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.984833
# --------------------------------------------------------------------------------
# Epoch 53 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.132712
# --------------------------------------------------------------------------------
# Epoch 54 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.041180
# --------------------------------------------------------------------------------
# Epoch 55 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.347467
# --------------------------------------------------------------------------------
# Epoch 56 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.760247
# --------------------------------------------------------------------------------
# Epoch 57 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.652719
# --------------------------------------------------------------------------------
# Epoch 58 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.506869
# --------------------------------------------------------------------------------
# Epoch 59 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.412591
# --------------------------------------------------------------------------------
# Epoch 60 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.585728
# --------------------------------------------------------------------------------
# Epoch 61 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.719744
# --------------------------------------------------------------------------------
# Epoch 62 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.941360
# --------------------------------------------------------------------------------
# Epoch 63 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.842094
# --------------------------------------------------------------------------------
# Epoch 64 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.114110
# --------------------------------------------------------------------------------
# Epoch 65 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.900258
# --------------------------------------------------------------------------------
# Epoch 66 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.566916
# --------------------------------------------------------------------------------
# Epoch 67 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.913791
# --------------------------------------------------------------------------------
# Epoch 68 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.824245
# --------------------------------------------------------------------------------
# Epoch 69 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.824098
# --------------------------------------------------------------------------------
# Epoch 70 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.579478
# --------------------------------------------------------------------------------
# Epoch 71 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 2.001657
# --------------------------------------------------------------------------------
# Epoch 72 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.746509
# --------------------------------------------------------------------------------
# Epoch 73 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.780981
# --------------------------------------------------------------------------------
# Epoch 74 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.738605
# --------------------------------------------------------------------------------
# Epoch 75 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.878975
# --------------------------------------------------------------------------------
# Epoch 76 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.710003
# --------------------------------------------------------------------------------
# Epoch 77 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.719070
# --------------------------------------------------------------------------------
# Epoch 78 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.901756
# --------------------------------------------------------------------------------
# Epoch 79 |   Training | Elapsed Time: 0:00:21 | Steps: 85 | Loss: 1.894172
# WARNING:tensorflow:From /content/DeepSpeech/training/deepspeech_training/util/checkpoints.py:71: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# W1216 21:20:09.793761 139703907256192 deprecation.py:323] From /content/DeepSpeech/training/deepspeech_training/util/checkpoints.py:71: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# --------------------------------------------------------------------------------
# I FINISHED optimization in 0:31:08.856624
# I Could not find best validating checkpoint.
# I Loading most recent checkpoint from /content/drive/MyDrive/nlp-project/xiaoyu-baseline/20201216-154833-b8-e80/checkpoints/train-6800
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: global_step
# I Loading variable from checkpoint: layer_1/bias
# I Loading variable from checkpoint: layer_1/weights
# I Loading variable from checkpoint: layer_2/bias
# I Loading variable from checkpoint: layer_2/weights
# I Loading variable from checkpoint: layer_3/bias
# I Loading variable from checkpoint: layer_3/weights
# I Loading variable from checkpoint: layer_5/bias
# I Loading variable from checkpoint: layer_5/weights
# I Loading variable from checkpoint: layer_6/bias
# I Loading variable from checkpoint: layer_6/weights
# Testing model on /content/drive/MyDrive/nlp-project/cmu_arctic/test/test_files.csv
# Test epoch | Steps: 120 | Elapsed Time: 0:01:37
# WARNING:tensorflow:From /content/DeepSpeech/training/deepspeech_training/train.py:708: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# W1216 21:21:47.585676 139703907256192 module_wrapper.py:139] From /content/DeepSpeech/training/deepspeech_training/train.py:708: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# WARNING:tensorflow:From /content/DeepSpeech/training/deepspeech_training/train.py:807: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1216 21:21:47.693209 139703907256192 module_wrapper.py:139] From /content/DeepSpeech/training/deepspeech_training/train.py:807: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/DeepSpeech/training/deepspeech_training/train.py:825: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W1216 21:21:48.102846 139703907256192 deprecation.py:323] From /content/DeepSpeech/training/deepspeech_training/train.py:825: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W1216 21:21:48.103039 139703907256192 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 12 variables.
# I1216 21:21:48.145069 139703907256192 graph_util_impl.py:334] Froze 12 variables.
# INFO:tensorflow:Converted 12 variables to const ops.
# I1216 21:21:48.378702 139703907256192 graph_util_impl.py:394] Converted 12 variables to const ops.
# Test on /content/drive/MyDrive/nlp-project/cmu_arctic/test/test_files.csv - WER: 0.829457, CER: 0.352762, loss: 117.956123
# --------------------------------------------------------------------------------
# Best WER:
# --------------------------------------------------------------------------------
# WER: 0.250000, CER: 0.093750, loss: 27.190277
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0167.wav
#  - src: "i was near the cabin and saw you"
#  - res: "i was nere the cabin and sal you"
# --------------------------------------------------------------------------------
# WER: 0.363636, CER: 0.166667, loss: 75.332275
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0170.wav
#  - src: "there was none of the joy of meeting in his face"
#  - res: "there was non of the jotive weing in his face"
# --------------------------------------------------------------------------------
# WER: 0.500000, CER: 0.309524, loss: 119.719627
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0180.wav
#  - src: "if not let's say our prayers and go to bed"
#  - res: "if not lipsaar prayere's and go to baid"
# --------------------------------------------------------------------------------
# WER: 0.500000, CER: 0.233333, loss: 60.331337
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/indian_male_40/arctic_a0183.wav
#  - src: "and the air was growing chilly"
#  - res: "and the are was gling chhely"
# --------------------------------------------------------------------------------
# WER: 0.500000, CER: 0.218750, loss: 49.464161
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0194.wav
#  - src: "he drank of the water cautiously"
#  - res: "he drainke of the wattere cashiousely"
# --------------------------------------------------------------------------------
# Median WER:
# --------------------------------------------------------------------------------
# WER: 0.857143, CER: 0.521739, loss: 218.759659
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0177.wav
#  - src: "she had been thoroughly and efficiently mauled"
#  - res: "she had bind fhirlyy ane fithiot ling ald"
# --------------------------------------------------------------------------------
# WER: 0.857143, CER: 0.369565, loss: 184.749130
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0177.wav
#  - src: "she had been thoroughly and efficiently mauled"
#  - res: "she hadbeent  forely ind ifficioling mallld"
# --------------------------------------------------------------------------------
# WER: 0.857143, CER: 0.391304, loss: 163.421219
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/indian_male_40/arctic_a0177.wav
#  - src: "she had been thoroughly and efficiently mauled"
#  - res: "she had been tarlwly ad hi fationt e molnd"
# --------------------------------------------------------------------------------
# WER: 0.875000, CER: 0.404762, loss: 179.847046
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0179.wav
#  - src: "tomorrow i'm going after that bear he said"
#  - res: "to mo one gon affid at bere he said"
# --------------------------------------------------------------------------------
# WER: 0.875000, CER: 0.400000, loss: 145.929031
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/indian_male_40/arctic_a0172.wav
#  - src: "gregson had left the outer door slightly ajar"
#  - res: "gregsu had lerfteouter dowerslitiees a"
# --------------------------------------------------------------------------------
# Worst WER:
# --------------------------------------------------------------------------------
# WER: 1.125000, CER: 0.488372, loss: 176.508606
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0165.wav
#  - src: "they are to attack your camp tomorrow night"
#  - res: "there t wa s acker cam to mo mit"
# --------------------------------------------------------------------------------
# WER: 1.125000, CER: 0.244444, loss: 90.891243
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0172.wav
#  - src: "gregson had left the outer door slightly ajar"
#  - res: "gregsin hod leff te oter dors slitly ad jar"
# --------------------------------------------------------------------------------
# WER: 1.142857, CER: 0.444444, loss: 151.208130
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/female_40/arctic_a0198.wav
#  - src: "sometimes her dreams were filled with visions"
#  - res: "sem temst ere dream smer phild wth fheins"
# --------------------------------------------------------------------------------
# WER: 1.166667, CER: 0.333333, loss: 90.883179
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/male_40/arctic_a0162.wav
#  - src: "that's the sub foreman explained thorpe"
#  - res: "thets the subge form men explingd tho wor"
# --------------------------------------------------------------------------------
# WER: 1.200000, CER: 0.527273, loss: 224.207306
#  - wav: file:///content/drive/MyDrive/nlp-project/cmu_arctic/test/audio/indian_male_40/arctic_a0178.wav
#  - src: "every bone in her aged body seemed broken or dislocated"
#  - res: "eveleid bounin her as hid pady seing grocon out th s ouciteed"
# --------------------------------------------------------------------------------
# I Exporting the model...
# I Could not find best validating checkpoint.
# I Loading most recent checkpoint from /content/drive/MyDrive/nlp-project/xiaoyu-baseline/20201216-154833-b8-e80/checkpoints/train-6800
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/bias
# I Loading variable from checkpoint: cudnn_lstm/rnn/multi_rnn_cell/cell_0/cudnn_compatible_lstm_cell/kernel
# I Loading variable from checkpoint: layer_1/bias
# I Loading variable from checkpoint: layer_1/weights
# I Loading variable from checkpoint: layer_2/bias
# I Loading variable from checkpoint: layer_2/weights
# I Loading variable from checkpoint: layer_3/bias
# I Loading variable from checkpoint: layer_3/weights
# I Loading variable from checkpoint: layer_5/bias
# I Loading variable from checkpoint: layer_5/weights
# I Loading variable from checkpoint: layer_6/bias
# I Loading variable from checkpoint: layer_6/weights
# I Models exported at /content/drive/MyDrive/nlp-project/xiaoyu-baseline/20201216-154833-b8-e80/models
# I Model metadata file saved to /content/drive/MyDrive/nlp-project/xiaoyu-baseline/20201216-154833-b8-e80/models/author_model_0.0.1.md. Before submitting the exported model for publishing make sure all information in the metadata file is correct, and complete the URL fields.
